# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd drive/'My Drive'/'Colab Notebooks'/
# %ls
# Out:
# [Errno 2] No such file or directory: 'drive/My Drive/Colab Notebooks/'
# /content/drive/My Drive/Colab Notebooks
# EDA.ipynb        equipment_C.csv   sample_submit.csv  track_C.csv
# equipment_A.csv  equipment_D.csv   track_A.csv        track_D.csv
# equipment_B.csv  index_master.csv  track_B.csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %%time
tracks={}
for no in ['A','B','C','D']:
    tracks[no] = pd.read_csv("dataset/track_" + no + ".csv", parse_dates=["date"])
# Out:
# CPU times: user 1min 2s, sys: 7.83 s, total: 1min 10s
# Wall time: 1min 14s

# %%
# %%time
equipments={}
for no in ['A','B','C','D']:
    equipments[no] = pd.read_csv("equipment_" + no + ".csv")
# Out:
# CPU times: user 83.4 ms, sys: 7.6 ms, total: 91 ms
# Wall time: 102 ms

# %%
from datetime import date
import datetime

# %%
from tqdm import tqdm

# %%
# %%time
for no in tqdm(['A','B','C','D']):
    track = tracks[no]
    track['day'] = [(date - datetime.datetime(2017, 4, 1)).days
                    for date in track['date']]
# Out:
# 100%|██████████| 4/4 [11:52<00:00, 172.27s/it]
# CPU times: user 11min 45s, sys: 7.12 s, total: 11min 52s
# Wall time: 11min 52s

# %%
from sklearn.linear_model import LinearRegression

# %%
def linear_plot(data, target):
    X = data.loc[data[target].notnull(), 'day'].values
    X = X.reshape(len(X), 1)
    y = data[target].dropna().values

    clf = LinearRegression()
    clf.fit(X, y)

    plt.plot(X, y, marker=".", linewidth=0)
    plt.plot(X, clf.predict(X))

# %%
data = track[track["キロ程"]==22809]
target = '高低左'
linear_plot(data, target)

# %%
data = track[track["キロ程"]==22809]
target = '高低右'
linear_plot(data, target)

# %%
data = track[track["キロ程"]==22809]
target = '通り左'
linear_plot(data, target)

# %%
data = track[track["キロ程"]==22809]
target = '通り右'
linear_plot(data, target)

# %%
data = track[track["キロ程"]==22809]
target = '水準'
linear_plot(data, target)

# %%
data = track[track["キロ程"]==22809]
target = '軌間'
linear_plot(data, target)

# %%
track = tracks['A']
corr = track.drop(['date', 'キロ程'], axis=1)
corr['高低左+高低左ma'] = corr['高低左'] + corr['高低左'].rolling(window=3, min_periods=1, center=True).mean()*1.5 - corr['高低左']*0.5
corr['高低右+高低右ma'] = corr['高低右'] + corr['高低右'].rolling(window=3, min_periods=1, center=True).mean()*1.5 - corr['高低右']*0.5
corr['高低左-高低右'] = corr['高低左'] - corr['高低右']
corr['水準+高低右'] = corr['水準'] + corr['高低右']
corr['水準+高低右+高低右ma'] = corr['水準'] + corr['高低右+高低右ma']
corr['通り左-通り右'] = corr['通り左'] - corr['通り右']

# %%
plt.figure(figsize=(12, 9))
sns.heatmap(corr.corr(), annot=True, square=True, cmap='Blues')

# %%
corr.corr()['高低左']
# Out:
# 高低左             1.000000
# 高低右             0.859896
# 通り左            -0.024764
# 通り右             0.000893
# 水準              0.127706
# 軌間             -0.008493
# 速度             -0.001637
# 高低左+高低左ma       0.998826
# 高低右+高低右ma       0.860334
# 高低左-高低右         0.213442
# 水準+高低右          0.882024
# 水準+高低右+高低右ma    0.924518
# 通り左-通り右        -0.031301
# Name: 高低左, dtype: float64

# %%
corr.corr()['高低左+高低左ma']
# Out:
# 高低左             0.998826
# 高低右             0.860946
# 通り左            -0.023907
# 通り右             0.000304
# 水準              0.127283
# 軌間             -0.007281
# 速度             -0.001773
# 高低左+高低左ma       1.000000
# 高低右+高低右ma       0.863255
# 高低左-高低右         0.209266
# 水準+高低右          0.882732
# 水準+高低右+高低右ma    0.927339
# 通り左-通り右        -0.029519
# Name: 高低左+高低左ma, dtype: float64

# %%
corr.corr()['水準']
# Out:
# 高低左       -0.222149
# 高低右        0.185463
# 通り左       -0.094029
# 通り右       -0.093476
# 水準         1.000000
# 軌間        -0.008710
# 速度        -0.000831
# day        0.000695
# 高低左-高低右   -0.768035
# 通り左-通り右    0.000955
# Name: 水準, dtype: float64

# %%
from sklearn import svm

# %%
clf = svm.OneClassSVM(nu=0.05, kernel='rbf', gamma=0.0001)
X = track[track["キロ程"]==22809]["高低左"].dropna()
X = X.reshape([len(X), 1])
clf.fit(X)
y_pred = clf.predict(X)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
print(sum(y_pred == 1), sum(y_pred == -1))
# Out:
# 193 12

# %%
check_outlier = pd.DataFrame(track[track["キロ程"]==22809]["高低左"].dropna())
check_outlier['out'] = y_pred

# %%
plt.scatter(check_outlier[check_outlier['out'] == 1].index, check_outlier.loc[check_outlier['out'] == 1, '高低左'], c='b')
plt.scatter(check_outlier[check_outlier['out'] == -1].index, check_outlier.loc[check_outlier['out'] == -1, '高低左'], c='r')

# %%
data = track[track["キロ程"]==22809]
target = '高低左'
linear_plot(data, target)

# %%
import math

# %%
def get_slope(days, koutei):
    kilos =  track['キロ程'].unique()
    slopes = []
    clf = LinearRegression()
    for kilo in tqdm(kilos):
        target = [i  for i in range(len(track)) if track.loc[i, "キロ程"] == kilo and not math.isnan(track.loc[i, '高低左'])]
        X = track.loc[target, 'day'].values
        X = X.reshape(len(X), 1)
        y = track.loc[target, '高低左'].values

        clf.fit(X, y)
        slope = clf.coef_[0]
        slopes.append(slope)

    return slopes

# %%
summarys = pd.DataFrame()
for no in tqdm(['A','B','C','D']):
    track = tracks[no][:100000]
    equipment = equipments[no]
    
    summary = pd.DataFrame(columns=['キロ程', 'rosen', 'slope'])
    summary['キロ程'] = track['キロ程'].unique()
    summary['rosen'] = no
    kilos =  track['キロ程'].unique()
    for kilo in kilos:
        
    days = track['days']
    koutei = track['高低左']
    summary['slope'] = get_slope(days, koutei)

    describe = track.groupby('キロ程').describe()
    cols = []
    for col in describe.columns:
        cols.append(col[0] + '_' + col[1])
    describe.columns = cols
    describe = describe.reset_index(drop=True)

    summary = pd.concat([summary, describe, equipment.drop('キロ程', axis=1)], axis=1)

    summarys = pd.concat([summarys, summary], axis=0)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|          | 0/27906 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|          | 1/27906 [00:00<6:38:17,  1.17it/s]
#
#
#
#
#
#   0%|          | 2/27906 [00:01<6:35:23,  1.18it/s]
#
#
#
#
#
#   0%|          | 3/27906 [00:02<6:34:43,  1.18it/s]
#
#
#
#
#
#   0%|          | 4/27906 [00:03<6:38:07,  1.17it/s]
#
#
#
#
#
#   0%|          | 5/27906 [00:04<6:39:20,  1.16it/s]
#
#
#
#
#
#   0%|          | 6/27906 [00:05<6:41:04,  1.16it/s]
#
#
#
#
#
#   0%|          | 7/27906 [00:06<6:42:35,  1.15it/s]
#
#
#
#
#
#   0%|          | 8/27906 [00:06<6:44:07,  1.15it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-124-62182a7738c7> in <module>()
#       7     kilo['キロ程'] = track['キロ程'].unique()
#       8     kilo['rosen'] = no
# ----> 9     kilo['slope'] = get_slope(track)
#      10
#      11     describe = track.groupby('キロ程').describe()
#
# <ipython-input-122-16de1b0499c6> in get_slope(track)
#       4     clf = LinearRegression()
#       5     for kilo in tqdm(kilos):
# ----> 6         target = [i  for i in range(len(track)) if track.loc[i, "キロ程"] == kilo and not math.isnan(track.loc[i, '高低左'])]
#       7         X = track.loc[target, 'day'].values
#       8         X = X.reshape(len(X), 1)
#
# <ipython-input-122-16de1b0499c6> in <listcomp>(.0)
#       4     clf = LinearRegression()
#       5     for kilo in tqdm(kilos):
# ----> 6         target = [i  for i in range(len(track)) if track.loc[i, "キロ程"] == kilo and not math.isnan(track.loc[i, '高低左'])]
#       7         X = track.loc[target, 'day'].values
#       8         X = X.reshape(len(X), 1)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1362             try:
#    1363                 if self._is_scalar_access(key):
# -> 1364                     return self._getitem_scalar(key)
#    1365             except (KeyError, IndexError):
#    1366                 pass
#
# KeyboardInterrupt:

# %%
kilos
# Out:
#            キロ程 rosen  slope  day_count  day_mean  day_std  day_min  day_25%  \
# 0      10000.0     A    0.0        1.0       0.0      NaN      0.0      0.0
# 1      10001.0     A    0.0        1.0       0.0      NaN      0.0      0.0
# 2      10002.0     A    0.0        1.0       0.0      NaN      0.0      0.0
# 3      10003.0     A    0.0        1.0       0.0      NaN      0.0      0.0
# 4      10004.0     A    0.0        1.0       0.0      NaN      0.0      0.0
# 5      10005.0     A    0.0        1.0       0.0      NaN      0.0      0.0
# 6      10006.0     A    0.0        1.0       0.0      NaN      0.0      0.0
# 7      10007.0     A    0.0        1.0       0.0      NaN      0.0      0.0
# 8      10008.0     A    0.0        1.0       0.0      NaN      0.0      0.0
# 9      10009.0     A    0.0        1.0       0.0      NaN      0.0      0.0
# 10         NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 11         NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 12         NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 13         NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 14         NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15         NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 16         NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 17         NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 18         NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 19         NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 20         NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 21         NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 22         NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 23         NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 24         NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 25         NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 26         NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 27         NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 28         NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 29         NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# ...        ...   ...    ...        ...       ...      ...      ...      ...
# 15661      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15662      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15663      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15664      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15665      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15666      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15667      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15668      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15669      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15670      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15671      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15672      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15673      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15674      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15675      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15676      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15677      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15678      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15679      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15680      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15681      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15682      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15683      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15684      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15685      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15686      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15687      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15688      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15689      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
# 15690      NaN   NaN    NaN        NaN       NaN      NaN      NaN      NaN
#
#        day_50%  day_75% ...   高低左_75%  高低左_max  バラスト  ロングレール  マクラギ種別  橋りょう  \
# 0          0.0      0.0 ...     -1.16    -1.16     1       1       3     0
# 1          0.0      0.0 ...     -1.17    -1.17     1       1       3     0
# 2          0.0      0.0 ...     -1.09    -1.09     1       1       3     0
# 3          0.0      0.0 ...     -0.64    -0.64     1       1       3     0
# 4          0.0      0.0 ...      0.47     0.47     1       1       1     0
# 5          0.0      0.0 ...      2.10     2.10     1       1       1     0
# 6          0.0      0.0 ...      3.61     3.61     1       1       1     0
# 7          0.0      0.0 ...      4.05     4.05     1       1       1     0
# 8          0.0      0.0 ...      2.71     2.71     1       1       1     0
# 9          0.0      0.0 ...     -0.29    -0.29     1       1       1     0
# 10         NaN      NaN ...       NaN      NaN     1       0       1     0
# 11         NaN      NaN ...       NaN      NaN     1       0       1     0
# 12         NaN      NaN ...       NaN      NaN     1       0       1     0
# 13         NaN      NaN ...       NaN      NaN     1       0       1     0
# 14         NaN      NaN ...       NaN      NaN     1       0       1     0
# 15         NaN      NaN ...       NaN      NaN     1       0       1     0
# 16         NaN      NaN ...       NaN      NaN     1       0       1     0
# 17         NaN      NaN ...       NaN      NaN     1       0       1     0
# 18         NaN      NaN ...       NaN      NaN     1       0       1     0
# 19         NaN      NaN ...       NaN      NaN     1       0       1     0
# 20         NaN      NaN ...       NaN      NaN     1       0       1     0
# 21         NaN      NaN ...       NaN      NaN     1       0       1     0
# 22         NaN      NaN ...       NaN      NaN     1       0       1     0
# 23         NaN      NaN ...       NaN      NaN     1       0       1     0
# 24         NaN      NaN ...       NaN      NaN     1       0       1     0
# 25         NaN      NaN ...       NaN      NaN     1       0       1     0
# 26         NaN      NaN ...       NaN      NaN     1       0       1     0
# 27         NaN      NaN ...       NaN      NaN     1       0       1     0
# 28         NaN      NaN ...       NaN      NaN     1       0       1     0
# 29         NaN      NaN ...       NaN      NaN     1       0       1     0
# ...        ...      ... ...       ...      ...   ...     ...     ...   ...
# 15661      NaN      NaN ...       NaN      NaN     1       0       1     0
# 15662      NaN      NaN ...       NaN      NaN     1       0       1     0
# 15663      NaN      NaN ...       NaN      NaN     1       0       1     0
# 15664      NaN      NaN ...       NaN      NaN     1       0       1     0
# 15665      NaN      NaN ...       NaN      NaN     1       0       1     0
# 15666      NaN      NaN ...       NaN      NaN     1       0       1     0
# 15667      NaN      NaN ...       NaN      NaN     1       0       1     0
# 15668      NaN      NaN ...       NaN      NaN     1       0       1     0
# 15669      NaN      NaN ...       NaN      NaN     1       0       1     0
# 15670      NaN      NaN ...       NaN      NaN     1       0       1     0
# 15671      NaN      NaN ...       NaN      NaN     1       0       1     0
# 15672      NaN      NaN ...       NaN      NaN     1       0       1     0
# 15673      NaN      NaN ...       NaN      NaN     1       0       1     0
# 15674      NaN      NaN ...       NaN      NaN     1       0       1     0
# 15675      NaN      NaN ...       NaN      NaN     1       0       1     0
# 15676      NaN      NaN ...       NaN      NaN     1       0       1     0
# 15677      NaN      NaN ...       NaN      NaN     1       0       1     0
# 15678      NaN      NaN ...       NaN      NaN     1       0       1     0
# 15679      NaN      NaN ...       NaN      NaN     1       0       1     0
# 15680      NaN      NaN ...       NaN      NaN     1       0       1     0
# 15681      NaN      NaN ...       NaN      NaN     1       0       2     0
# 15682      NaN      NaN ...       NaN      NaN     1       0       1     0
# 15683      NaN      NaN ...       NaN      NaN     1       0       1     0
# 15684      NaN      NaN ...       NaN      NaN     1       0       1     0
# 15685      NaN      NaN ...       NaN      NaN     1       0       1     0
# 15686      NaN      NaN ...       NaN      NaN     1       0       1     0
# 15687      NaN      NaN ...       NaN      NaN     1       0       1     0
# 15688      NaN      NaN ...       NaN      NaN     1       0       2     0
# 15689      NaN      NaN ...       NaN      NaN     1       0       2     0
# 15690      NaN      NaN ...       NaN      NaN     1       0       1     0
#
#        踏切     通トン  曲線半径  フラグ
# 0       0  13.607     0    1
# 1       0  13.607     0    1
# 2       0  13.607     0    1
# 3       0  13.607     0    1
# 4       0  13.607     0    1
# 5       0  13.607     0    1
# 6       0  13.607     0    1
# 7       0  13.607     0    1
# 8       0  13.607     0    1
# 9       0  13.607     0    1
# 10      0  13.607     0    1
# 11      0  13.607     0    1
# 12      0  13.607     0    1
# 13      0  13.607  3200    0
# 14      0  13.607  3200    0
# 15      0  13.607  3200    0
# 16      0  13.607  3200    0
# 17      0  13.607  3200    0
# 18      0  13.607  3200    0
# 19      0  13.607  3200    0
# 20      0  13.607  3200    0
# 21      0  13.607  3200    0
# 22      0  13.607  3200    0
# 23      0  13.607  3200    0
# 24      0  13.607  3200    0
# 25      0  13.607  3200    0
# 26      0  13.607  3200    0
# 27      0  13.607  3200    0
# 28      0  13.607  3200    0
# 29      0  13.607  3200    0
# ...    ..     ...   ...  ...
# 15661   0   0.812     0    0
# 15662   0   0.812     0    0
# 15663   0   0.812     0    0
# 15664   0   0.812     0    0
# 15665   0   0.812     0    0
# 15666   0   0.812     0    0
# 15667   0   0.812     0    0
# 15668   0   0.812     0    0
# 15669   0   0.812     0    0
# 15670   0   0.812     0    0
# 15671   0   0.812     0    0
# 15672   0   0.812     0    0
# 15673   0   0.812     0    0
# 15674   0   0.812     0    0
# 15675   0   0.812     0    0
# 15676   0   0.812     0    0
# 15677   0   0.812     0    0
# 15678   0   0.812     0    0
# 15679   0   0.812     0    0
# 15680   0   0.812     0    0
# 15681   0   0.812     0    0
# 15682   0   0.812     0    0
# 15683   0   0.812     0    0
# 15684   0   0.812     0    0
# 15685   0   0.812     0    0
# 15686   0   0.812     0    0
# 15687   0   0.812     0    0
# 15688   0   0.812     0    0
# 15689   0   0.812     0    0
# 15690   0   0.812     0    0
#
# [120812 rows x 75 columns]

# %%
for i in ['バラスト', 'フラグ', 'マクラギ種別', 'ロングレール', '踏切', '橋りょう']:
    print(kilos.groupby(i).mean()['高低左_mean'])
# Out:
# バラスト
# 0    0.133318
# 1   -0.020616
# Name: 高低左_mean, dtype: float64
# フラグ
# 0   -0.001233
# 1    0.001633
# Name: 高低左_mean, dtype: float64
# マクラギ種別
# 1   -0.025974
# 2    0.251909
# 3    0.135527
# 5    0.391544
# 6    0.754793
# 7    5.857316
# 8    0.276320
# Name: 高低左_mean, dtype: float64
# ロングレール
# 0   -0.001335
# 1   -0.000857
# Name: 高低左_mean, dtype: float64
# 踏切
# 0   -0.010291
# 1    1.744016
# Name: 高低左_mean, dtype: float64
# 橋りょう
# 0   -0.021332
# 1    0.448034
# Name: 高低左_mean, dtype: float64

# %%
for i in ['バラスト', 'フラグ', 'マクラギ種別', 'ロングレール', '踏切', '橋りょう']:
    print(kilos.groupby(i).mean()['高低左_std'])
# Out:
# バラスト
# 0    0.927401
# 1    0.641795
# Name: 高低左_std, dtype: float64
# フラグ
# 0    0.619141
# 1    1.269833
# Name: 高低左_std, dtype: float64
# マクラギ種別
# 1    0.654929
# 2    0.905143
# 3    1.634061
# 5    0.594109
# 6    2.049579
# 7    0.449875
# 8    0.811244
# Name: 高低左_std, dtype: float64
# ロングレール
# 0    0.916646
# 1    0.607103
# Name: 高低左_std, dtype: float64
# 踏切
# 0    0.674836
# 1    1.310046
# Name: 高低左_std, dtype: float64
# 橋りょう
# 0    0.679906
# 1    0.641087
# Name: 高低左_std, dtype: float64
